# %%
# %load_ext autoreload
# %autoreload 2

# %%
from JacobianODE.jacobians.run_analytics import run_analytics

# %%
WANDB_ENTITY = "JacobianODE"
WANDB_PROJECT = "Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE"
run_id = "na2lkyj5"
SAVE_DIR = "/orcd/data/ekmiller/001/eisenaj/JacobianODE/lightning/latent_jac_runs"

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    run_id=run_id,
    output=["show"],
    epoch=10,
)
# Out:
# Loading run na2lkyj5 from JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE ...
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /home/eisenaj/.netrc.
# Sequence Indices:   0%|          | 0/1056 [00:00<?, ?it/s]
# Train dataset shape: torch.Size([23232, 45, 100])
# Validation dataset shape: torch.Size([7392, 45, 100])
# Test dataset shape: torch.Size([3168, 45, 100])
# Train trajectories dataset shape: torch.Size([22, 1101, 100])
# Validation trajectories dataset shape: torch.Size([7, 1101, 100])
# Test trajectories dataset shape: torch.Size([3, 1101, 100])
# Loading checkpoint epoch=10-step=550.ckpt...
# Skipping 'sweep_overview': provide wandb_group or precomputed sweep_diagnostics.
# Computing reconstruction ...
# Computing MASE ...
# MASE batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Teacher-forced MASE: 0.5735
# Free-running MASE:   2.6590
# Computing latent utilization ...
# Entropy-based utilization: 0.665
# Null subspace mean RMS: 1.197677e+00
# Computing Lyapunov exponents ...
#   Computing full-trajectory Lyapunov (3 test trajs, T=1101) ...
#     Traj 0: [-0.01916307 -0.57200074 -1.3006046 ]
#     Traj 1: [ 0.09008519 -0.32254863 -1.6378801 ]
#     Traj 2: [ 0.08707292 -0.3015265  -1.6416984 ]
# Predicted Lyapunov exponents (batch+burn-in, 128 windowed trajs):
#   λ_1 = -0.4926 ± 1.3558
#   λ_2 = -1.4510 ± 1.4096
#   λ_3 = -2.4100 ± 1.4225
# Predicted Lyapunov exponents (full-length, 3 test trajs):
#   λ_1 = +0.0527 ± 0.0622
#   λ_2 = -0.3987 ± 0.1505
#   λ_3 = -1.5267 ± 0.1958
# Empirical Lyapunov exponents (mean ± std):
#   λ_1 = +0.3846 ± 0.0251
#   λ_2 = -0.1716 ± 0.0444
#   λ_3 = -13.8799 ± 0.0398
# Mean KY dim (predicted): 0.856 ± 0.605
# Mean KY dim (empirical): 2.015 ± 0.002
# Computing prediction windows ...
# Windows: 636 — nMSE min=7.3866, median=9.6210, mean=9.6083, max=13.9104
# Computing long trajectory prediction ...
# Computing encoder/decoder Jacobians ...
# encoder_jacobian: (128, 100, 100)
# decoder_jacobian: (128, 100, 100)
# Computing amplification loss ...
# Amplification loss — True state: 0.000219
# Amplification loss — Latent:     0.000216

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    run_id=run_id,
    output=["show"],
    epoch=20,
)
# Out:
# Loading run na2lkyj5 from JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE ...
# Sequence Indices:   0%|          | 0/1056 [00:00<?, ?it/s]
# Train dataset shape: torch.Size([23232, 45, 100])
# Validation dataset shape: torch.Size([7392, 45, 100])
# Test dataset shape: torch.Size([3168, 45, 100])
# Train trajectories dataset shape: torch.Size([22, 1101, 100])
# Validation trajectories dataset shape: torch.Size([7, 1101, 100])
# Test trajectories dataset shape: torch.Size([3, 1101, 100])
# Loading checkpoint epoch=20-step=1050.ckpt...
# Skipping 'sweep_overview': provide wandb_group or precomputed sweep_diagnostics.
# Computing reconstruction ...
# Computing MASE ...
# MASE batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Teacher-forced MASE: 0.4999
# Free-running MASE:   2.3730
# Computing latent utilization ...
# Entropy-based utilization: 0.676
# Null subspace mean RMS: 1.091074e+00
# Computing Lyapunov exponents ...
#   Computing full-trajectory Lyapunov (3 test trajs, T=1101) ...
#     Traj 0: [-0.1944999 -0.9526583 -1.7121307]
#     Traj 1: [-0.10056765 -0.96936184 -1.7741508 ]
#     Traj 2: [-0.10294304 -0.8592972  -1.8441789 ]
# Predicted Lyapunov exponents (batch+burn-in, 128 windowed trajs):
#   λ_1 = -0.5090 ± 0.6792
#   λ_2 = -1.1857 ± 0.6351
#   λ_3 = -2.5256 ± 0.8502
# Predicted Lyapunov exponents (full-length, 3 test trajs):
#   λ_1 = -0.1327 ± 0.0536
#   λ_2 = -0.9271 ± 0.0593
#   λ_3 = -1.7768 ± 0.0661
# Empirical Lyapunov exponents (mean ± std):
#   λ_1 = +0.3846 ± 0.0251
#   λ_2 = -0.1716 ± 0.0444
#   λ_3 = -13.8799 ± 0.0398
# Mean KY dim (predicted): 0.000 ± 0.000
# Mean KY dim (empirical): 2.015 ± 0.002
# Computing prediction windows ...
# Windows: 636 — nMSE min=7.0508, median=9.6256, mean=9.6279, max=14.7788
# Computing long trajectory prediction ...
# Computing encoder/decoder Jacobians ...
# encoder_jacobian: (128, 100, 100)
# decoder_jacobian: (128, 100, 100)
# Computing amplification loss ...
# Amplification loss — True state: 0.000219
# Amplification loss — Latent:     0.000204

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    run_id=run_id,
    output=["show"],
    epoch=30,
)
# Out:
# Loading run na2lkyj5 from JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE ...
# Sequence Indices:   0%|          | 0/1056 [00:00<?, ?it/s]
# Train dataset shape: torch.Size([23232, 45, 100])
# Validation dataset shape: torch.Size([7392, 45, 100])
# Test dataset shape: torch.Size([3168, 45, 100])
# Train trajectories dataset shape: torch.Size([22, 1101, 100])
# Validation trajectories dataset shape: torch.Size([7, 1101, 100])
# Test trajectories dataset shape: torch.Size([3, 1101, 100])
# Loading checkpoint epoch=30-step=1550.ckpt...
# Skipping 'sweep_overview': provide wandb_group or precomputed sweep_diagnostics.
# Computing reconstruction ...
# Computing MASE ...
# MASE batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Teacher-forced MASE: 0.4633
# Free-running MASE:   1.2807
# Computing latent utilization ...
# Entropy-based utilization: 0.683
# Null subspace mean RMS: 9.835246e-01
# Computing Lyapunov exponents ...
#   Computing full-trajectory Lyapunov (3 test trajs, T=1101) ...
#     Traj 0: [ 0.36760488 -0.16181168 -2.927453  ]
#     Traj 1: [ 0.21369763  0.02264624 -2.9311376 ]
#     Traj 2: [ 0.16996203  0.12176143 -2.944635  ]
# Predicted Lyapunov exponents (batch+burn-in, 128 windowed trajs):
#   λ_1 = +nan ± nan
#   λ_2 = +nan ± nan
#   λ_3 = +nan ± nan
# Predicted Lyapunov exponents (full-length, 3 test trajs):
#   λ_1 = +0.2504 ± 0.1038
#   λ_2 = -0.0058 ± 0.1439
#   λ_3 = -2.9344 ± 0.0090
# Empirical Lyapunov exponents (mean ± std):
#   λ_1 = +0.3846 ± 0.0251
#   λ_2 = -0.1716 ± 0.0444
#   λ_3 = -13.8799 ± 0.0398
# Mean KY dim (predicted): 2.083 ± 0.012
# Mean KY dim (empirical): 2.015 ± 0.002
# Computing prediction windows ...
# Windows: 636 — nMSE min=7.5335, median=9.7098, mean=9.7590, max=15.2496
# Computing long trajectory prediction ...
# Computing encoder/decoder Jacobians ...
# encoder_jacobian: (128, 100, 100)
# decoder_jacobian: (128, 100, 100)
# Computing amplification loss ...
# Amplification loss — True state: 0.000219
# Amplification loss — Latent:     0.000196

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    run_id=run_id,
    output=["show"],
    epoch=50,
)
# Out:
# Loading run na2lkyj5 from JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE ...
# Sequence Indices:   0%|          | 0/1056 [00:00<?, ?it/s]
# Train dataset shape: torch.Size([23232, 45, 100])
# Validation dataset shape: torch.Size([7392, 45, 100])
# Test dataset shape: torch.Size([3168, 45, 100])
# Train trajectories dataset shape: torch.Size([22, 1101, 100])
# Validation trajectories dataset shape: torch.Size([7, 1101, 100])
# Test trajectories dataset shape: torch.Size([3, 1101, 100])
# Loading checkpoint epoch=50-step=2550.ckpt...
# Skipping 'sweep_overview': provide wandb_group or precomputed sweep_diagnostics.
# Computing reconstruction ...
# Computing MASE ...
# MASE batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Teacher-forced MASE: 0.4428
# Free-running MASE:   0.8506
# Computing latent utilization ...
# Entropy-based utilization: 0.699
# Null subspace mean RMS: 8.077180e-01
# Computing Lyapunov exponents ...
#   Computing full-trajectory Lyapunov (3 test trajs, T=1101) ...
#     Traj 0: [ 0.28046647 -0.19406593 -3.8553698 ]
#     Traj 1: [ 0.32571304 -0.09203001 -3.9554179 ]
#     Traj 2: [ 0.304086   -0.05545928 -3.948069  ]
# Predicted Lyapunov exponents (batch+burn-in, 128 windowed trajs):
#   λ_1 = +0.5649 ± 0.4384
#   λ_2 = -0.6064 ± 0.3729
#   λ_3 = -3.2325 ± 0.8371
# Predicted Lyapunov exponents (full-length, 3 test trajs):
#   λ_1 = +0.3034 ± 0.0226
#   λ_2 = -0.1139 ± 0.0718
#   λ_3 = -3.9196 ± 0.0558
# Empirical Lyapunov exponents (mean ± std):
#   λ_1 = +0.3846 ± 0.0251
#   λ_2 = -0.1716 ± 0.0444
#   λ_3 = -13.8799 ± 0.0398
# Mean KY dim (predicted): 2.048 ± 0.018
# Mean KY dim (empirical): 2.015 ± 0.002
# Computing prediction windows ...
# Windows: 636 — nMSE min=7.7987, median=9.5750, mean=9.6333, max=15.3955
# Computing long trajectory prediction ...
# Computing encoder/decoder Jacobians ...
# encoder_jacobian: (128, 100, 100)
# decoder_jacobian: (128, 100, 100)
# Computing amplification loss ...
# Amplification loss — True state: 0.000219
# Amplification loss — Latent:     0.000190

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    run_id=run_id,
    output=["show"],
    epoch=70,
)
# Out:
# Loading run na2lkyj5 from JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE ...
# Sequence Indices:   0%|          | 0/1056 [00:00<?, ?it/s]
# Train dataset shape: torch.Size([23232, 45, 100])
# Validation dataset shape: torch.Size([7392, 45, 100])
# Test dataset shape: torch.Size([3168, 45, 100])
# Train trajectories dataset shape: torch.Size([22, 1101, 100])
# Validation trajectories dataset shape: torch.Size([7, 1101, 100])
# Test trajectories dataset shape: torch.Size([3, 1101, 100])
# Loading checkpoint epoch=70-step=3550.ckpt...
# Skipping 'sweep_overview': provide wandb_group or precomputed sweep_diagnostics.
# Computing reconstruction ...
# Computing MASE ...
# MASE batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Teacher-forced MASE: 0.4401
# Free-running MASE:   0.7633
# Computing latent utilization ...
# Entropy-based utilization: 0.711
# Null subspace mean RMS: 7.094886e-01
# Computing Lyapunov exponents ...
#   Computing full-trajectory Lyapunov (3 test trajs, T=1101) ...
#     Traj 0: [ 0.32761273 -0.141341   -4.31203   ]
#     Traj 1: [ 0.37534776 -0.11013715 -4.34922   ]
#     Traj 2: [ 2.9301828e-01  2.4261083e-03 -4.3636856e+00]
# Predicted Lyapunov exponents (batch+burn-in, 128 windowed trajs):
#   λ_1 = +0.5428 ± 0.4077
#   λ_2 = -0.5247 ± 0.3303
#   λ_3 = -3.8316 ± 0.6795
# Predicted Lyapunov exponents (full-length, 3 test trajs):
#   λ_1 = +0.3320 ± 0.0413
#   λ_2 = -0.0830 ± 0.0756
#   λ_3 = -4.3416 ± 0.0266
# Empirical Lyapunov exponents (mean ± std):
#   λ_1 = +0.3846 ± 0.0251
#   λ_2 = -0.1716 ± 0.0444
#   λ_3 = -13.8799 ± 0.0398
# Mean KY dim (predicted): 2.057 ± 0.010
# Mean KY dim (empirical): 2.015 ± 0.002
# Computing prediction windows ...
# Windows: 636 — nMSE min=7.9928, median=9.4417, mean=9.5440, max=15.3776
# Computing long trajectory prediction ...
# Computing encoder/decoder Jacobians ...
# encoder_jacobian: (128, 100, 100)
# decoder_jacobian: (128, 100, 100)
# Computing amplification loss ...
# Amplification loss — True state: 0.000219
# Amplification loss — Latent:     0.000184

# %%
import datetime
import subprocess
import sys
from pathlib import Path

# Jupyter / this kernel use the repo's uv-managed environment (e.g. `.venv` here).
# `sys.executable -m nbconvert` runs nbconvert with that same interpreter, not a stray
# `jupyter` on PATH. Kernel cwd may still differ from the repo root, so we locate the
# `.ipynb` explicitly below.

NB_NAME = "2026-03-27 - Epoch Picking.ipynb"
# Kernel cwd is often the notebook folder, not repo root — try sensible locations.
for candidate in (
    Path.cwd() / NB_NAME,
    Path.cwd() / "_jupyter" / "_sandbox" / NB_NAME,
    Path.cwd().parent / "_sandbox" / NB_NAME,
):
    if candidate.is_file():
        notebook_path = candidate.resolve()
        break
else:
    raise FileNotFoundError(
        f"Could not find {NB_NAME}; cwd={Path.cwd()!s}"
    )

notebook_name = notebook_path.stem

now = datetime.datetime.now()
timestamp = now.strftime('%Y-%m-%d_%H-%M-%S')
output_dir = (notebook_path.parent / "../reports").resolve()
output_dir.mkdir(parents=True, exist_ok=True)
# nbconvert --output is the basename only; --output-dir sets the folder.
output_base = f"{timestamp}_{notebook_name}"
output_html = output_dir / f"{output_base}.html"

result = subprocess.run(
    [
        sys.executable,
        "-m",
        "nbconvert",
        "--to",
        "html",
        "--output",
        output_base,
        "--output-dir",
        str(output_dir),
        str(notebook_path),
    ],
    check=False,
)
if result.returncode != 0:
    raise RuntimeError(
        f"nbconvert failed with exit code {result.returncode}"
    )
print(f"Notebook saved as HTML: {output_html}")
# Out:
# [NbConvertApp] Converting notebook /orcd/home/002/eisenaj/code/JacobianODE/_jupyter/_sandbox/2026-03-27 - Epoch Picking.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 60 image(s).
# [NbConvertApp] Writing 5855242 bytes to /orcd/home/002/eisenaj/code/JacobianODE/_jupyter/reports/2026-03-27_15-34-05_2026-03-27 - Epoch Picking.html
# Notebook saved as HTML: /orcd/home/002/eisenaj/code/JacobianODE/_jupyter/reports/2026-03-27_15-34-05_2026-03-27 - Epoch Picking.html
