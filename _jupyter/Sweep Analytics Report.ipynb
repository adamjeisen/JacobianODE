# %%
# %load_ext autoreload
# %autoreload 2

# %%
from JacobianODE.jacobians.run_analytics import run_analytics

# %%
WANDB_ENTITY = "JacobianODE"
WANDB_PROJECT = "Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE"
# WANDB_GROUP = "sweep_from_scratch_spline_coupling_lc_9vals__klNNone_1.0__klD0_0.0001_0.001_0.01_0.1_1__te0.0_enc_warmup_5_vaetrue" # 108 runs
WANDB_GROUP = "sweep_from_scratch_spline_coupling_lc_9vals__klNnull__klD0_0.0001_0.001_0.01_0.1_1__te0.0_enc_warmup_5_vaetrue" # 54 runs (lc v kl_dyn_weight, pred_steps = 10)
SAVE_DIR = "/orcd/data/ekmiller/001/eisenaj/JacobianODE/lightning/latent_jac_runs"
TRUE_LYAPUNOV = [0.91, 0.0, -14.57]  # None for wmtask (overridden from config)

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    wandb_group=WANDB_GROUP,
    true_lyapunov=TRUE_LYAPUNOV,
    output=["show", "html"],
    output_dir="reports",
)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /home/eisenaj/.netrc.
# No run_id provided — selecting best run from group 'sweep_from_scratch_spline_coupling_lc_9vals__klNnull__klD0_0.0001_0.001_0.01_0.1_1__te0.0_enc_warmup_5_vaetrue' ...
# Found 54 total runs in JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE (group=sweep_from_scratch_spline_coupling_lc_9vals__klNnull__klD0_0.0001_0.001_0.01_0.1_1__te0.0_enc_warmup_5_vaetrue)
# All runs (state, loop_closure_weight, tangent_entropy_weight, kl_dyn_weight):
#   fzfgeu4z: state=finished, lc=0.0, te=0.0, kl_dyn=0.1
#   gwqd5m73: state=finished, lc=1e-06, te=0.0, kl_dyn=0.01
#   e79ptta1: state=finished, lc=1e-06, te=0.0, kl_dyn=0.001
#   kd8xvizb: state=finished, lc=0.0, te=0.0, kl_dyn=0.01
#   sz6cc9ka: state=finished, lc=1e-06, te=0.0, kl_dyn=0.0
#   loao70do: state=finished, lc=0.0, te=0.0, kl_dyn=0.001
#   gyz9krhx: state=finished, lc=1e-06, te=0.0, kl_dyn=1.0
#   ino3806w: state=finished, lc=1e-05, te=0.0, kl_dyn=0.0
#   kgg7fvuq: state=finished, lc=1e-06, te=0.0, kl_dyn=0.0001
#   pfbz42qd: state=finished, lc=0.0, te=0.0, kl_dyn=1.0
#   htkiphmv: state=finished, lc=1e-06, te=0.0, kl_dyn=0.1
#   4lnfvedo: state=finished, lc=0.0, te=0.0, kl_dyn=0.0
#   a0s9r9eu: state=finished, lc=0.0, te=0.0, kl_dyn=0.0001
#   n20bnoeo: state=finished, lc=1e-05, te=0.0, kl_dyn=0.001
#   i4cepk0h: state=finished, lc=1e-05, te=0.0, kl_dyn=0.0001
#   zy68uytd: state=finished, lc=1e-05, te=0.0, kl_dyn=0.01
#   8xba5umc: state=finished, lc=1e-05, te=0.0, kl_dyn=0.1
#   3unqi4qr: state=finished, lc=1e-05, te=0.0, kl_dyn=1.0
#   krhtuj54: state=finished, lc=0.0001, te=0.0, kl_dyn=0.0
#   2f4236oz: state=finished, lc=0.0001, te=0.0, kl_dyn=0.0001
#   6hd8xi0b: state=finished, lc=0.01, te=0.0, kl_dyn=0.0
#   mpsqstw7: state=finished, lc=0.001, te=0.0, kl_dyn=0.0001
#   5dznq4z5: state=finished, lc=0.001, te=0.0, kl_dyn=1.0
#   jz9nhggi: state=finished, lc=0.001, te=0.0, kl_dyn=0.0
#   t2upxqfa: state=finished, lc=0.001, te=0.0, kl_dyn=0.1
#   p6yjhx62: state=finished, lc=0.001, te=0.0, kl_dyn=0.001
#   mjbo6zlg: state=finished, lc=0.0001, te=0.0, kl_dyn=0.001
#   d28174gn: state=finished, lc=0.001, te=0.0, kl_dyn=0.01
#   b9c6dgn8: state=finished, lc=0.0001, te=0.0, kl_dyn=0.01
#   0m8jfv3m: state=finished, lc=0.0001, te=0.0, kl_dyn=1.0
#   t4ht3w22: state=finished, lc=0.0001, te=0.0, kl_dyn=0.1
#   h7sltuci: state=finished, lc=0.01, te=0.0, kl_dyn=0.0001
#   smtwdh7r: state=finished, lc=0.01, te=0.0, kl_dyn=0.001
#   h97a4bje: state=finished, lc=0.01, te=0.0, kl_dyn=0.01
#   89dehzzy: state=finished, lc=0.01, te=0.0, kl_dyn=0.1
#   3jl625r6: state=finished, lc=0.01, te=0.0, kl_dyn=1.0
#   907fu0qa: state=finished, lc=0.1, te=0.0, kl_dyn=0.0
#   pf5ljvmv: state=finished, lc=1.0, te=0.0, kl_dyn=0.0001
#   x27ecjv0: state=finished, lc=0.1, te=0.0, kl_dyn=1.0
#   i2trtv3m: state=finished, lc=1.0, te=0.0, kl_dyn=0.01
#   twqnkfkr: state=finished, lc=1.0, te=0.0, kl_dyn=0.0
#   w1hnyp1b: state=finished, lc=1.0, te=0.0, kl_dyn=0.001
#   5v14zd0f: state=finished, lc=0.1, te=0.0, kl_dyn=0.001
#   zg1srd77: state=finished, lc=0.1, te=0.0, kl_dyn=0.0001
#   9fq0o8t3: state=finished, lc=0.1, te=0.0, kl_dyn=0.01
#   u5e4s2tw: state=finished, lc=0.1, te=0.0, kl_dyn=0.1
#   s8iuhbgv: state=finished, lc=1.0, te=0.0, kl_dyn=0.1
#   xe4r9xto: state=finished, lc=1.0, te=0.0, kl_dyn=1.0
#   i3pb9sgi: state=finished, lc=10.0, te=0.0, kl_dyn=0.0
#   12yez9sv: state=finished, lc=10.0, te=0.0, kl_dyn=0.0001
#   4pg5xww6: state=finished, lc=10.0, te=0.0, kl_dyn=0.001
#   tk77o9dd: state=finished, lc=10.0, te=0.0, kl_dyn=0.1
#   kd0t66ni: state=finished, lc=10.0, te=0.0, kl_dyn=0.01
#   v58lmpp0: state=finished, lc=10.0, te=0.0, kl_dyn=1.0
#
# Found 54 finished sweep runs:
#   loop_closure_weight=0.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=4lnfvedo
#   loop_closure_weight=0.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=a0s9r9eu
#   loop_closure_weight=0.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=loao70do
#   loop_closure_weight=0.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=kd8xvizb
#   loop_closure_weight=0.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=fzfgeu4z
#   loop_closure_weight=0.0, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=pfbz42qd
#   loop_closure_weight=1e-06, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=sz6cc9ka
#   loop_closure_weight=1e-06, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=kgg7fvuq
#   loop_closure_weight=1e-06, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=e79ptta1
#   loop_closure_weight=1e-06, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=gwqd5m73
#   loop_closure_weight=1e-06, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=htkiphmv
#   loop_closure_weight=1e-06, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=gyz9krhx
#   loop_closure_weight=1e-05, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=ino3806w
#   loop_closure_weight=1e-05, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=i4cepk0h
#   loop_closure_weight=1e-05, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=n20bnoeo
#   loop_closure_weight=1e-05, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=zy68uytd
#   loop_closure_weight=1e-05, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=8xba5umc
#   loop_closure_weight=1e-05, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=3unqi4qr
#   loop_closure_weight=0.0001, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=krhtuj54
#   loop_closure_weight=0.0001, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=2f4236oz
#   loop_closure_weight=0.0001, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=mjbo6zlg
#   loop_closure_weight=0.0001, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=b9c6dgn8
#   loop_closure_weight=0.0001, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=t4ht3w22
#   loop_closure_weight=0.0001, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=0m8jfv3m
#   loop_closure_weight=0.001, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=jz9nhggi
#   loop_closure_weight=0.001, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=mpsqstw7
#   loop_closure_weight=0.001, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=p6yjhx62
#   loop_closure_weight=0.001, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=d28174gn
#   loop_closure_weight=0.001, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=t2upxqfa
#   loop_closure_weight=0.001, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=5dznq4z5
#   loop_closure_weight=0.01, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=6hd8xi0b
#   loop_closure_weight=0.01, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=h7sltuci
#   loop_closure_weight=0.01, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=smtwdh7r
#   loop_closure_weight=0.01, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=h97a4bje
#   loop_closure_weight=0.01, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=89dehzzy
#   loop_closure_weight=0.01, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=3jl625r6
#   loop_closure_weight=0.1, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=907fu0qa
#   loop_closure_weight=0.1, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=zg1srd77
#   loop_closure_weight=0.1, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=5v14zd0f
#   loop_closure_weight=0.1, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=9fq0o8t3
#   loop_closure_weight=0.1, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=u5e4s2tw
#   loop_closure_weight=0.1, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=x27ecjv0
#   loop_closure_weight=1.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=twqnkfkr
#   loop_closure_weight=1.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=pf5ljvmv
#   loop_closure_weight=1.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=w1hnyp1b
#   loop_closure_weight=1.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=i2trtv3m
#   loop_closure_weight=1.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=s8iuhbgv
#   loop_closure_weight=1.0, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=xe4r9xto
#   loop_closure_weight=10.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.0 -> run_id=i3pb9sgi
#   loop_closure_weight=10.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.0001 -> run_id=12yez9sv
#   loop_closure_weight=10.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.001 -> run_id=4pg5xww6
#   loop_closure_weight=10.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.01 -> run_id=kd0t66ni
#   loop_closure_weight=10.0, tangent_entropy_weight=0.0, kl_dyn_weight=0.1 -> run_id=tk77o9dd
#   loop_closure_weight=10.0, tangent_entropy_weight=0.0, kl_dyn_weight=1.0 -> run_id=v58lmpp0
# n_dims=3, n_latent=3, n_dyn=3, dt=0.0150
#   run=4lnfvedo: DiagnosticMetrics(one_step_mase=0.4350075423717499, loop_closure_loss=179.64007568359375, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007659327238798141) (from W&B history)
#   run=a0s9r9eu: DiagnosticMetrics(one_step_mase=0.4312063157558441, loop_closure_loss=162.7874755859375, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007420150213874876) (from W&B history)
#   run=loao70do: DiagnosticMetrics(one_step_mase=0.4238049387931824, loop_closure_loss=86.47906494140625, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0006955143762752414) (from W&B history)
#   run=kd8xvizb: DiagnosticMetrics(one_step_mase=0.4282827377319336, loop_closure_loss=40.14997863769531, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007467460818588734) (from W&B history)
#   run=fzfgeu4z: DiagnosticMetrics(one_step_mase=0.4545750916004181, loop_closure_loss=3.931171178817749, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0011170789366587996) (from W&B history)
#   run=pfbz42qd: DiagnosticMetrics(one_step_mase=0.6298010945320129, loop_closure_loss=0.055965252220630646, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0016442391788586974) (from W&B history)
#   run=sz6cc9ka: DiagnosticMetrics(one_step_mase=0.4254217743873596, loop_closure_loss=12.25021743774414, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.000683355494402349) (from W&B history)
#   run=kgg7fvuq: DiagnosticMetrics(one_step_mase=0.42277956008911133, loop_closure_loss=12.7684907913208, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0006827908218838274) (from W&B history)
#   run=e79ptta1: DiagnosticMetrics(one_step_mase=0.4264564514160156, loop_closure_loss=23.362390518188477, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007911865250207484) (from W&B history)
#   run=gwqd5m73: DiagnosticMetrics(one_step_mase=0.4279990494251251, loop_closure_loss=22.518028259277344, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007538988720625639) (from W&B history)
#   run=htkiphmv: DiagnosticMetrics(one_step_mase=0.45520341396331787, loop_closure_loss=3.9809186458587646, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0010964738903567195) (from W&B history)
#   run=gyz9krhx: DiagnosticMetrics(one_step_mase=0.6299029588699341, loop_closure_loss=0.05257552117109299, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0016377988504245877) (from W&B history)
#   run=ino3806w: DiagnosticMetrics(one_step_mase=0.4267176389694214, loop_closure_loss=2.479310989379883, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.000718683295417577) (from W&B history)
#   run=i4cepk0h: DiagnosticMetrics(one_step_mase=0.4226515293121338, loop_closure_loss=2.3132266998291016, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.00071978650521487) (from W&B history)
#   run=n20bnoeo: DiagnosticMetrics(one_step_mase=0.41970184445381165, loop_closure_loss=1.1497291326522827, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007129607838578522) (from W&B history)
#   run=zy68uytd: DiagnosticMetrics(one_step_mase=0.4270601272583008, loop_closure_loss=1.786659836769104, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007601901888847351) (from W&B history)
#   run=8xba5umc: DiagnosticMetrics(one_step_mase=0.462820440530777, loop_closure_loss=0.5620151162147522, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0012558771995827556) (from W&B history)
#   run=3unqi4qr: DiagnosticMetrics(one_step_mase=0.6098413467407227, loop_closure_loss=0.06145857647061348, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.00154982041567564) (from W&B history)
#   run=krhtuj54: DiagnosticMetrics(one_step_mase=0.4256739914417267, loop_closure_loss=0.2474522441625595, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007263884763233364) (from W&B history)
#   run=2f4236oz: DiagnosticMetrics(one_step_mase=0.4222351610660553, loop_closure_loss=0.23109066486358643, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007225149311125278) (from W&B history)
#   run=mjbo6zlg: DiagnosticMetrics(one_step_mase=0.42347392439842224, loop_closure_loss=0.2266998291015625, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007896439637988806) (from W&B history)
#   run=b9c6dgn8: DiagnosticMetrics(one_step_mase=0.43113943934440613, loop_closure_loss=0.10883679240942001, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008670581737533212) (from W&B history)
#   run=t4ht3w22: DiagnosticMetrics(one_step_mase=0.45604750514030457, loop_closure_loss=0.12746788561344147, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.001122570363804698) (from W&B history)
#   run=0m8jfv3m: DiagnosticMetrics(one_step_mase=0.6064914464950562, loop_closure_loss=0.03902049362659454, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0016442685155197978) (from W&B history)
#   run=jz9nhggi: DiagnosticMetrics(one_step_mase=0.4270685315132141, loop_closure_loss=0.016145145520567894, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008058510138653219) (from W&B history)
#   run=mpsqstw7: DiagnosticMetrics(one_step_mase=0.42312857508659363, loop_closure_loss=0.01588054560124874, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008081492269411683) (from W&B history)
#   run=p6yjhx62: DiagnosticMetrics(one_step_mase=0.42373794317245483, loop_closure_loss=0.020130641758441925, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008468536543659866) (from W&B history)
#   run=d28174gn: DiagnosticMetrics(one_step_mase=0.4305865466594696, loop_closure_loss=0.009510339237749577, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008640445885248482) (from W&B history)
#   run=t2upxqfa: DiagnosticMetrics(one_step_mase=0.4575522541999817, loop_closure_loss=0.010604888200759888, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0011312362039461732) (from W&B history)
#   run=5dznq4z5: DiagnosticMetrics(one_step_mase=0.6267315149307251, loop_closure_loss=0.004741783253848553, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.001579420524649322) (from W&B history)
#   run=6hd8xi0b: DiagnosticMetrics(one_step_mase=0.4243987202644348, loop_closure_loss=0.0023817983455955982, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.000765417527873069) (from W&B history)
#   run=h7sltuci: DiagnosticMetrics(one_step_mase=0.42294156551361084, loop_closure_loss=0.004259607754647732, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0007980201626196504) (from W&B history)
#   run=smtwdh7r: DiagnosticMetrics(one_step_mase=0.42934030294418335, loop_closure_loss=0.0021129194647073746, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008989745401777327) (from W&B history)
#   run=h97a4bje: DiagnosticMetrics(one_step_mase=0.43737006187438965, loop_closure_loss=0.00040564764640294015, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008442744147032499) (from W&B history)
#   run=89dehzzy: DiagnosticMetrics(one_step_mase=0.46129247546195984, loop_closure_loss=0.00037376818363554776, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0011083983117714524) (from W&B history)
#   run=3jl625r6: DiagnosticMetrics(one_step_mase=0.6286375522613525, loop_closure_loss=0.00038341470644809306, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0015795968938618898) (from W&B history)
#   run=907fu0qa: DiagnosticMetrics(one_step_mase=0.4294855296611786, loop_closure_loss=0.00018238576012663543, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008589547942392528) (from W&B history)
#   run=zg1srd77: DiagnosticMetrics(one_step_mase=0.4343700706958771, loop_closure_loss=0.0002587804337963462, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0010412116535007954) (from W&B history)
#   run=5v14zd0f: DiagnosticMetrics(one_step_mase=0.4304192364215851, loop_closure_loss=0.0001007943574222736, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0009573339484632015) (from W&B history)
#   run=9fq0o8t3: DiagnosticMetrics(one_step_mase=0.43740588426589966, loop_closure_loss=7.118226494640112e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008526796009391546) (from W&B history)
#   run=u5e4s2tw: DiagnosticMetrics(one_step_mase=0.4545094072818756, loop_closure_loss=4.7749417717568576e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0011946007143706083) (from W&B history)
#   run=x27ecjv0: DiagnosticMetrics(one_step_mase=0.6234936118125916, loop_closure_loss=3.895148984156549e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0015778333181515336) (from W&B history)
#   run=twqnkfkr: DiagnosticMetrics(one_step_mase=0.43982458114624023, loop_closure_loss=3.1458373996429145e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.00109501788392663) (from W&B history)
#   run=pf5ljvmv: DiagnosticMetrics(one_step_mase=0.4359000027179718, loop_closure_loss=2.8083135475753807e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0010946540860459208) (from W&B history)
#   run=w1hnyp1b: DiagnosticMetrics(one_step_mase=0.42909470200538635, loop_closure_loss=4.4209005864104256e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0009910912485793233) (from W&B history)
#   run=i2trtv3m: DiagnosticMetrics(one_step_mase=0.4330616593360901, loop_closure_loss=2.6437173801241443e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0008839286747388542) (from W&B history)
#   run=s8iuhbgv: DiagnosticMetrics(one_step_mase=0.4559219181537628, loop_closure_loss=3.151659620925784e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0013066004030406475) (from W&B history)
#   run=xe4r9xto: DiagnosticMetrics(one_step_mase=0.60964035987854, loop_closure_loss=5.330551630322589e-06, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0016030026599764824) (from W&B history)
#   run=i3pb9sgi: DiagnosticMetrics(one_step_mase=0.4725423753261566, loop_closure_loss=1.148975297837751e-05, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0014340776251628995) (from W&B history)
#   run=12yez9sv: DiagnosticMetrics(one_step_mase=0.4790772497653961, loop_closure_loss=6.9698044171673246e-06, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0016428071539849043) (from W&B history)
#   run=4pg5xww6: DiagnosticMetrics(one_step_mase=0.4636960029602051, loop_closure_loss=2.4124374249367975e-06, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0016016795998439193) (from W&B history)
#   run=kd0t66ni: DiagnosticMetrics(one_step_mase=0.4357716739177704, loop_closure_loss=9.614264854462817e-06, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.001026566606014967) (from W&B history)
#   run=tk77o9dd: DiagnosticMetrics(one_step_mase=0.4686838388442993, loop_closure_loss=3.2830628242663806e-06, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.0015507658245041966) (from W&B history)
#   run=v58lmpp0: DiagnosticMetrics(one_step_mase=0.6340073347091675, loop_closure_loss=1.5682651621773402e-07, fast_eigenvalue_fraction=0.0, trajectory_val_loss=0.001921791466884315) (from W&B history)
#
# Best run ID:              n20bnoeo
# Best loop_closure_weight: 1e-05
# Best tangent_entropy_weight: 0.0
# Best kl_dyn_weight:       0.001
# Best traj loss:           0.000713
# Criteria applied: ['C1', 'C2', 'C3']
# Surviving: 41 / 54
# Auto-selected run_id: n20bnoeo
# Loading run n20bnoeo from JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE ...
# Sequence Indices:   0%|          | 0/1076 [00:00<?, ?it/s]
# Train dataset shape: torch.Size([23672, 25, 100])
# Validation dataset shape: torch.Size([7532, 25, 100])
# Test dataset shape: torch.Size([3228, 25, 100])
# Train trajectories dataset shape: torch.Size([22, 1101, 100])
# Validation trajectories dataset shape: torch.Size([7, 1101, 100])
# Test trajectories dataset shape: torch.Size([3, 1101, 100])
# Loading checkpoint epoch=122-step=6150.ckpt...
# HTML report will be saved to: reports/2026-03-27_12-18-11__Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE__n20bnoeo.html
# Computing reconstruction ...
# Computing MASE ...
# MASE batches:   0%|          | 0/10 [00:00<?, ?it/s]
# Teacher-forced MASE: 0.4154
# Free-running MASE:   0.4541
# Computing latent utilization ...
# Entropy-based utilization: 0.734
# Null subspace mean RMS: 2.459348e-01
# Computing Lyapunov exponents ...
#   Computing full-trajectory Lyapunov (3 test trajs, T=1101) ...
#     Traj 0: [ 0.278189    0.04258819 -6.4960747 ]
#     Traj 1: [ 0.5012596  -0.10500016 -6.4535556 ]
#     Traj 2: [ 0.49595246 -0.08677377 -6.480076  ]
# Predicted Lyapunov exponents (batch+burn-in, 128 windowed trajs):
#   λ_1 = +0.6485 ± 0.5764
#   λ_2 = -0.9395 ± 0.4436
#   λ_3 = -6.1605 ± 0.7336
# Predicted Lyapunov exponents (full-length, 3 test trajs):
#   λ_1 = +0.4251 ± 0.1273
#   λ_2 = -0.0497 ± 0.0805
#   λ_3 = -6.4766 ± 0.0215
# True:      [0.91, 0.0, -14.57]
# Empirical Lyapunov exponents (mean ± std):
#   λ_1 = +0.3846 ± 0.0251
#   λ_2 = -0.1716 ± 0.0444
#   λ_3 = -13.8799 ± 0.0398
# Mean KY dim (predicted): 2.058 ± 0.006
# Mean KY dim (empirical): 2.015 ± 0.002
# KY dim (theory):         2.062
# Computing prediction windows ...
# Windows: 648 — nMSE min=4.8675, median=6.0945, mean=6.2831, max=11.3789
# Computing long trajectory prediction ...
# Computing encoder/decoder Jacobians ...
# encoder_jacobian: (128, 100, 100)
# decoder_jacobian: (128, 100, 100)
# Computing amplification loss ...
# Amplification loss — True state: 0.000219
# Amplification loss — Latent:     0.000187
# HTML report saved to: reports/2026-03-27_12-18-11__Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE__n20bnoeo.html
