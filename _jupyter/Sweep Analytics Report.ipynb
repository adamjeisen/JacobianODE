# %%
# %load_ext autoreload
# %autoreload 2

# %%
from JacobianODE.jacobians.run_analytics import run_analytics

# %%
WANDB_ENTITY = "JacobianODE"

# WANDB_PROJECT = "Lorenz_IND0_N100_D1_NormTrue_T3__spline_coupling__JacobianODE"
# # WANDB_GROUP = "sweep_from_scratch_spline_coupling_lc_9vals__klNNone_1.0__klD0_0.0001_0.001_0.01_0.1_1__te0.0_enc_warmup_5_vaetrue" # 108 runs
# WANDB_GROUP = "sweep_from_scratch_spline_coupling_lc_9vals__klNnull__klD0_0.0001_0.001_0.01_0.1_1__te0.0_enc_warmup_5_vaetrue" # 54 runs (lc v kl_dyn_weight, pred_steps = 10)

WANDB_PROJECT = "Lorenz_IND0_N100_D1_NormTrue_T7__spline_coupling__JacobianODE"
WANDB_GROUP = None

SAVE_DIR = "/orcd/data/ekmiller/001/eisenaj/JacobianODE/lightning/latent_jac_runs"
TRUE_LYAPUNOV = [0.91, 0.0, -14.57]  # None for wmtask (overridden from config)

# %%
run_analytics(
    wandb_entity=WANDB_ENTITY,
    wandb_project=WANDB_PROJECT,
    save_dir=SAVE_DIR,
    wandb_group=WANDB_GROUP,
    true_lyapunov=TRUE_LYAPUNOV,
    # output=["show", "html"],
    output=["show"],
    output_dir="reports",
)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /home/eisenaj/.netrc.
# No run_id provided — selecting best run from all runs in 'Lorenz_IND0_N100_D1_NormTrue_T7__spline_coupling__JacobianODE' ...
# Found 54 total runs in JacobianODE/Lorenz_IND0_N100_D1_NormTrue_T7__spline_coupling__JacobianODE
# All runs (state, loop_closure_weight, tangent_entropy_weight, kl_dyn_weight):
#   27gnizkv: state=finished, lc=0.0, te=0.0, kl_dyn=0.0
#   fhehg2u2: state=finished, lc=0.0, te=0.0, kl_dyn=0.001
#   ncuierwk: state=finished, lc=0.0, te=0.0, kl_dyn=0.0001
#   y25fmbon: state=finished, lc=0.0, te=0.0, kl_dyn=0.01
#   aevga8qb: state=finished, lc=1e-06, te=0.0, kl_dyn=0.0
#   9mw5awqp: state=finished, lc=0.0, te=0.0, kl_dyn=1.0
#   fvfy55wd: state=finished, lc=0.0, te=0.0, kl_dyn=0.1
#   5m0we10d: state=finished, lc=1e-06, te=0.0, kl_dyn=0.0001
#   do8bichd: state=finished, lc=1e-06, te=0.0, kl_dyn=0.001
#   qca0eo3b: state=finished, lc=1e-06, te=0.0, kl_dyn=0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_analytics(
#       2     wandb_entity=WANDB_ENTITY,
#       3     wandb_project=WANDB_PROJECT,
#       4     save_dir=SAVE_DIR,
#       5     wandb_group=WANDB_GROUP,
#       6     true_lyapunov=TRUE_LYAPUNOV,
#       7     output=["show", "html"],
#       8     output_dir="reports",
#       9 )
#
# File /orcd/home/002/eisenaj/code/JacobianODE/JacobianODE/jacobians/run_analytics.py:803, in run_analytics(wandb_entity, wandb_project, save_dir, run_id, epoch, wandb_group, true_lyapunov, output, output_dir, sections, device, n_sample, n_mase_batches, n_amp_trajs, n_amp_neighbors, n_amp_max_t, n_pred_trajs, lyapunov_burn_in_steps, lyapunov_burn_in_drop, sweep_diagnostics, sweep_result, sweep_lambdas)
#     801 else:
#     802     print(f"No run_id provided — selecting best run from all runs in '{wandb_project}' ...")
# --> 803 run_id, _auto_sweep_result, _auto_discovered = select_best_from_sweep(
#     804     wandb_entity=wandb_entity,
#     805     wandb_project=wandb_project,
#     806     save_dir=save_dir,
#     807     wandb_group=wandb_group,
#     808     verbose=True,
#     809 )
#     810 print(f"Auto-selected run_id: {run_id}")
#     812 # Populate sweep precomputed args so sweep_overview doesn't re-run
#
# File /orcd/home/002/eisenaj/code/JacobianODE/JacobianODE/jacobians/tuning/sweep.py:607, in select_best_from_sweep(wandb_entity, wandb_project, save_dir, wandb_group, n_batches, eigenvalue_threshold, use_loop_closure, delete_crashed, verbose)
#     564 """Discover sweep runs and select the best one.
#     565
#     566 Convenience wrapper that calls :func:`discover_sweep_runs` then
#    (...)    603     If no finished sweep runs are found or selection fails.
#     604 """
#     605 from ..checkpoints import load_run
# --> 607 discovered = discover_sweep_runs(
#     608     wandb_entity, wandb_project, wandb_group,
#     609     delete_crashed=delete_crashed, verbose=verbose,
#     610 )
#     612 if not discovered.run_ids:
#     613     group_msg = f" group={wandb_group}" if wandb_group else ""
#
# File /orcd/home/002/eisenaj/code/JacobianODE/JacobianODE/jacobians/tuning/sweep.py:491, in discover_sweep_runs(wandb_entity, wandb_project, wandb_group, delete_crashed, verbose)
#     489 print("All runs (state, loop_closure_weight, tangent_entropy_weight, kl_dyn_weight):")
#     490 for r in all_runs:
# --> 491     lc = _get_loop_closure_weight(r)
#     492     te = _get_tangent_entropy_weight(r)
#     493     kd = _get_kl_dyn_weight(r)
#
# File /orcd/home/002/eisenaj/code/JacobianODE/JacobianODE/jacobians/tuning/sweep.py:377, in _get_loop_closure_weight(run)
#     375 """Robustly extract ``loop_closure_weight`` from a W&B run config."""
#     376 try:
# --> 377     val = run.config.get("training", {}).get("lightning", {}).get("loop_closure_weight")
#     378     if val is not None:
#     379         return float(val)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/apis/public/runs.py:1415, in Run.config(self)
#    1413 """Get run config. Auto-loads full data if in lazy mode."""
#    1414 if self._lazy and not self._full_data_loaded and "config" not in self._attrs:
# -> 1415     self.load_full_data()
#    1417 # Ensure config is always converted to dict (defensive against conversion issues)
#    1418 config_value = self._attrs.get("config", {})
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/apis/public/runs.py:1407, in Run.load_full_data(self, force)
#    1404     return self._attrs
#    1406 # Load full data and mark as loaded
# -> 1407 result = self._load_with_fragment(RUN_FRAGMENT, RUN_FRAGMENT_NAME, force=True)
#    1408 self._full_data_loaded = True
#    1409 return result
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/apis/public/runs.py:745, in Run._load_with_fragment(self, fragment, fragment_name, force)
#     730 query = gql(
#     731     f"""
#     732 query Run($project: String!, $entity: String!, $name: String!) {{
#    (...)    741 """
#     742 )
#     744 if force or not self._attrs:
# --> 745     response = self._exec(query)
#     746     if (
#     747         response is None
#     748         or response.get("project") is None
#     749         or response["project"].get("run") is None
#     750     ):
#     751         raise ValueError("Could not find run {}".format(self))
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/apis/public/runs.py:1010, in Run._exec(self, query, **kwargs)
#    1008 variables = {"entity": self.entity, "project": self.project, "name": self.id}
#    1009 variables.update(kwargs)
# -> 1010 return self.client.execute(query, variable_values=variables)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/apis/public/api.py:113, in RetryingClient.execute(self, *args, **kwargs)
#     111 if self._execute_decorated is None:
#     112     self._execute_decorated = self._build_execute_wrapper()
# --> 113 return self._execute_decorated(*args, **kwargs)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/sdk/lib/retry.py:322, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     320 @functools.wraps(fn)
#     321 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 322     return retrier(*args, **kargs)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/sdk/lib/retry.py:160, in Retry.__call__(self, num_retries, retry_timedelta, retry_sleep_base, retry_cancel_event, check_retry_fn, *args, **kwargs)
#     158 while True:
#     159     try:
# --> 160         result = self._call_fn(*args, **kwargs)
#     162     except self._retryable_exceptions as e:
#     163         if not retry_loop.should_retry(e):
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/apis/public/api.py:125, in RetryingClient._build_execute_wrapper.<locals>._wrapped(*args, **kwargs)
#     118 @retry.retriable(
#     119     retry_timedelta=RETRY_TIMEDELTA,
#     120     check_retry_fn=util.no_retry_auth,
#     121     retryable_exceptions=(RetryError, requests.RequestException),
#     122 )
#     123 def _wrapped(*args, **kwargs):
#     124     try:
# --> 125         return self._client.execute(*args, **kwargs)
#     126     except requests.exceptions.ReadTimeout:
#     127         if "timeout" not in kwargs:
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:52, in Client.execute(self, document, *args, **kwargs)
#      49 if self.schema:
#      50     self.validate(document)
# ---> 52 result = self._get_result(document, *args, **kwargs)
#      53 if result.errors:
#      54     raise Exception(str(result.errors[0]))
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:60, in Client._get_result(self, document, *args, **kwargs)
#      58 def _get_result(self, document, *args, **kwargs):
#      59     if not self.retries:
# ---> 60         return self.transport.execute(document, *args, **kwargs)
#      62     last_exception = None
#      63     retries_count = 0
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/wandb/sdk/lib/gql_request.py:70, in GraphQLSession.execute(self, document, variable_values, timeout)
#      62     headers.update(func_info.to_headers())
#      64 post_args = {
#      65     "headers": headers or None,
#      66     "cookies": self.cookies,
#      67     "timeout": timeout or self.default_timeout,
#      68     data_key: payload,
#      69 }
# ---> 70 request = self.session.post(self.url, **post_args)
#      71 request.raise_for_status()
#      73 result = request.json()
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)    634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/code/JacobianODE/.venv/lib64/python3.12/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib64/python3.12/http/client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File /usr/lib64/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/lib64/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/lib64/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /usr/lib64/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib64/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
